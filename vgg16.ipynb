# %%
import pandas as pd 
import numpy as np

from time import sleep
from tqdm import tqdm

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.datasets import mnist

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import VGG16

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def add_padding(dataset=None, pad_width = 0, constant_values=0) -> []:
    padded_dataset = []
    
    for i in dataset:
        padded = np.pad(i, pad_width=pad_width, mode='constant', constant_values=constant_values)
        padded_dataset.append(padded[:, :, np.newaxis])
    
    return padded_dataset

def extract_features(dataset):
    features = []

    for x in tqdm(dataset):
        p = np.repeat(x, 3, axis=-1)
        p = preprocess_input(p)
        predict = np.expand_dims(p, axis=0)
        predict = model.predict(predict)
        features.append(predict[0][0][0])
    
    return features
    
def write_matrix_to_file(matrix=None, file_name="random.txt"):
    with open(file_name, 'wb') as f:
        for line in matrix:
            np.savetxt(f, line, delimiter=' ')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

new_x_train = add_padding(x_train, pad_width=2, constant_values=0)
new_x_test = add_padding(x_test, pad_width=2, constant_values=0)

# %%
model = VGG16(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

# %%
train_features = extract_features(new_x_train)

# %%
test_features = extract_features(new_x_test)
# Out:
#   0%|▊                                                                                                                                                                                                 | 41/10000 [00:01<07:44, 21.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1016888/343345523.py in <module>
# ----> 1 test_features = extract_features(new_x_test)
#
# /tmp/ipykernel_1016888/4279059701.py in extract_features(dataset)
#      15         p = preprocess_input(p)
#      16         predict = np.expand_dims(p, axis=0)
# ---> 17         predict = model.predict(predict)
#      18         features.append(predict[0][0][0])
#      19
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1949               stacklevel=2)
#    1950
# -> 1951       data_handler = data_adapter.get_data_handler(
#    1952           x=x,
#    1953           batch_size=batch_size,
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1147
#    1148     adapter_cls = select_data_adapter(x, y)
# -> 1149     self._adapter = adapter_cls(
#    1150         x,
#    1151         y,
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     324       return flat_dataset
#     325
# --> 326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
#     328     dataset = self.slice_inputs(indices_dataset, inputs)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2058       Dataset: A `Dataset`.
#    2059     """
# -> 2060     return FlatMapDataset(self, map_func, name=name)
#    2061
#    2062   def interleave(self,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5277     """See `Dataset.flat_map()` for details."""
#    5278     self._input_dataset = input_dataset
# -> 5279     self._map_func = structured_function.StructuredFunctionWrapper(
#    5280         map_func, self._transformation_name(), dataset=input_dataset)
#    5281     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     269         fn_factory = trace_tf_function(defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#     273     add_to_graph &= not context.executing_eagerly()
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3068          or `tf.Tensor` or `tf.TensorSpec`.
#    3069     """
# -> 3070     graph_function = self._get_concrete_function_garbage_collected(
#    3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034       args, kwargs = None, None
#    3035     with self._lock:
# -> 3036       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037       seen_names = set()
#    3038       captured = object_identity.ObjectIdentitySet(
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3128     arg_names = base_arg_names + missing_arg_names
#    3129     graph_function = ConcreteFunction(
# -> 3130         func_graph_module.func_graph_from_py_func(
#    3131             self._name,
#    3132             self._python_function,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1159         _, original_func = tf_decorator.unwrap(python_func)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#    1163       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     246           attributes=defun_kwargs)
#     247       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 248         ret = wrapper_helper(*args)
#     249         ret = structure.to_tensor_list(self._output_structure, ret)
#     250         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py in wrapper_helper(*args)
#     175       if not _should_unpack(nested_args):
#     176         nested_args = (nested_args,)
# --> 177       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     178       if _should_pack(ret):
#     179         ret = tuple(ret)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in slice_batch_indices(indices)
#     315       flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     316       if self._partial_batch_size:
# --> 317         index_remainder = tf.data.Dataset.from_tensors(tf.slice(
#     318             indices, [num_in_full_batch], [self._partial_batch_size]))
#     319         flat_dataset = flat_dataset.concatenate(index_remainder)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in slice(input_, begin, size, name)
#    1117     A `Tensor` the same type as `input_`.
#    1118   """
# -> 1119   return gen_array_ops._slice(input_, begin, size, name=name)
#    1120
#    1121
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py in _slice(input, begin, size, name)
#    9580       pass  # Add nodes to the TensorFlow graph.
#    9581   # Add nodes to the TensorFlow graph.
# -> 9582   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9583         "Slice", input=input, begin=begin, size=size, name=name)
#    9584   _result = _outputs[:]
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     506                   preferred_dtype=default_dtype)
#     507           else:
# --> 508             values = ops.convert_to_tensor(
#     509                 values,
#     510                 name=input_arg.name,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#     344
#     345
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#     269
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288   attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     291
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691       inp = self.capture(inp)
#     692       captured_inputs.append(inp)
# --> 693     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695         compute_device)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3774     # Session.run call cannot occur between creating and mutating the op.
#    3775     with self._mutation_lock():
# -> 3776       ret = Operation(
#    3777           node_def,
#    3778           self,
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169       if op_def is None:
#    2170         op_def = self._graph._get_op_def(node_def.op)
# -> 2171       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                                 control_input_ops, op_def)
#    2173       name = compat.as_str(node_def.name)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2000
#    2001   # Add attrs
# -> 2002   for name, attr_value in node_def.attr.items():
#    2003     serialized = attr_value.SerializeToString()
#    2004     # TODO(skyewm): this creates and deletes a new TF_Status for every attr.
#
# ~/anaconda3/lib/python3.9/_collections_abc.py in __iter__(self)
#     848
#     849     def __iter__(self):
# --> 850         for key in self._mapping:
#     851             yield (key, self._mapping[key])
#     852
#
# KeyboardInterrupt:

# %%
train_features = np.matrix(features)
write_matrix_to_file(train_features, file_name="vgg16_train_features.out")

# %%
test_features = np.matrix(test_features)
write_matrix_to_file(test_features, file_name="vgg16_test_features.out")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1016888/4077083494.py in <module>
# ----> 1 print(test_features.shape)
#       2 # test_features = np.matrix(test_features)
#       3 # test_features.shape
#       4 # write_matrix_to_file(test_features, file_name="vgg16_test_features.out")
#
# AttributeError: 'NoneType' object has no attribute 'shape'
